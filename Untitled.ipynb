# %%
a = int(input(" take value of a"))
b = int (input ("take value of b"))
c = a +b 
print(c)
# Out:
#  take value of a10
# take value of b7
# 17

# %%
import matplotlib.pyplot as plt
x = [1 ,2,3,4,5,6]
y = [1,2,3,4,5,6]
plt.plot(x,y)
plt.show()
